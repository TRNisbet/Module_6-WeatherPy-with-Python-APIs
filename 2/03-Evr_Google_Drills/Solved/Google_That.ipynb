# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target URLs and multiple API requests.

# Dependencies
import requests
import json

# Google API Key
from config import gkey

# %%
# 1. What are the geocoordinates (latitude and longitude) of Seattle,
# Washington?
target_city = "Seattle, Washington"

params = {"address": target_city, "key": gkey}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

print("Drill #1: The Geocoordinates of Seattle, WA")

# Run request
response = requests.get(base_url, params=params)

# Convert to JSON
seattle_geo = response.json()

# Extract lat/lng
lat = seattle_geo["results"][0]["geometry"]["location"]["lat"]
lng = seattle_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
print(f"{target_city}: {lat}, {lng}")
# Out:
# Drill #1: The Geocoordinates of Seattle, WA
# Seattle, Washington: 47.6062095, -122.3320708

# %%
# 2. What are the geocoordinates (latitude and longitude) of The White House?
# update params dict
target_city = "The White House"
params["address"] = target_city


print("Drill #2: The Geocoordinates of the White House")


# Run request
response = requests.get(base_url, params=params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

dc_geo = response.json()
# Extract lat/lng
lat = dc_geo["results"][0]["geometry"]["location"]["lat"]
lng = dc_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
print(f"{target_city}: {lat}, {lng}")
# Out:
# Drill #2: The Geocoordinates of the White House
# The White House: 38.8976763, -77.0365298

# %%
# 3. Find the name and address of a bike store in Seattle, Washington.
#    Hint: See https://developers.google.com/places/web-service/supported_types
target_type = "bicycle_store"
seattle_coords = "47.6062095,-122.3320708"
radius = 8000

# rewrite params dict

params = {
    "location": seattle_coords,
    "types": target_type,
    "radius": radius,
    "key": gkey
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

print("Drill #3: A Bike Store in Seattle, WA")

# Run request
response = requests.get(base_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
print(response.url)

seattle_bikes = response.json()

# Print the JSON (pretty printed)
print(json.dumps(seattle_bikes, indent=4, sort_keys=True))

# Print the name and address of the first bike shop to appear
print(seattle_bikes["results"][0]["name"])
print(seattle_bikes["results"][0]["vicinity"])
# Out:
# Drill #3: A Bike Store in Seattle, WA
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=47.6062095%2C-122.3320708&types=bicycle_store&radius=8000&key=AIzaSyBOvLmPulB3Y5xiUsQzkdWMn95x8pYe5Es
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6203442,
#                     "lng": -122.3297537
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.62143328029151,
#                         "lng": -122.3285603197085
#                     },
#                     "southwest": {
#                         "lat": 47.61873531970851,
#                         "lng": -122.3312582802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "REI",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112174674445766631734\">Jason House</a>"
#                     ],
#                     "photo_reference": "AcYSjRh9MRqAUKpWj_9VwyQiseiWFCTw5W3simvZ_8v8BzaB-I-7C-ptRgdrwLFvwIZsM-xqvGuBQyC5SXXdUv6MXBBww3HXJDAs3iI1LNV5fQqf3v2ANSx5fhh8xvPWgIKNu28oyysU9XLlf_3I3TUcucuPXJ5t5Eol88tJ5YszmY3YXEF0",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJa_52_zMVkFQRIsX5KSvv41k",
#             "plus_code": {
#                 "compound_code": "JMCC+43 Seattle, WA, USA",
#                 "global_code": "84VVJMCC+43"
#             },
#             "price_level": 3,
#             "rating": 4.7,
#             "reference": "ChIJa_52_zMVkFQRIsX5KSvv41k",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "shoe_store",
#                 "clothing_store",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2712,
#             "vicinity": "222 Yale Avenue North, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6186545,
#                     "lng": -122.3307729
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6199252802915,
#                         "lng": -122.3294348697085
#                     },
#                     "southwest": {
#                         "lat": 47.6172273197085,
#                         "lng": -122.3321328302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "Play It Again Sports & Ski",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111393759693279042582\">Edward Aites</a>"
#                     ],
#                     "photo_reference": "AcYSjRhBQ4j-9pjPE0g_PvEhdtQ4zgI3efi15gf9807HfXEaER9qsDKWGT52JfYqb-1u_ZGFkZyaGu719il0XgIaCBMG_ALu-hUMr4AtLR-XBCStFS3IrxeseviLymtroO4u6y-h-eQZrpeKNr9MrevK3-E3dVy77665DSZmUNBApuqlJroy",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJU5tNPjQVkFQRUDMcQiJNK9U",
#             "plus_code": {
#                 "compound_code": "JM99+FM Seattle, WA, USA",
#                 "global_code": "84VVJM99+FM"
#             },
#             "rating": 4,
#             "reference": "ChIJU5tNPjQVkFQRUDMcQiJNK9U",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 120,
#             "vicinity": "1304 Stewart Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6130575,
#                     "lng": -122.3053228
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6143391302915,
#                         "lng": -122.3039231197085
#                     },
#                     "southwest": {
#                         "lat": 47.6116411697085,
#                         "lng": -122.3066210802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "20/20 Cycle",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1134,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114847554661145085738\">Chan (\u6211\u7684\u4e16\u754c - My world)</a>"
#                     ],
#                     "photo_reference": "AcYSjRgSdkzzH_-f_Ju1h3UKo5WBL3q7FAi7C6j2fp_IPIqiRrU1oD1SpL4LGIMk34FKGkfXWRUPMC7HPhksmwBnhr9_i8LECmQk0M3ub_13S5ARU5UpK3iPwOLYTgUvky0ZZvIvyYTvfFLjDCKMoQ2ln6x1_paKBUJBx6IM33JYKIsLukyB",
#                     "width": 1700
#                 }
#             ],
#             "place_id": "ChIJaw6Z7dBqkFQR2uo5k5IGigs",
#             "plus_code": {
#                 "compound_code": "JM7V+6V Seattle, WA, USA",
#                 "global_code": "84VVJM7V+6V"
#             },
#             "rating": 4.6,
#             "reference": "ChIJaw6Z7dBqkFQR2uo5k5IGigs",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 125,
#             "vicinity": "2020 East Union Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6127018,
#                     "lng": -122.3186498
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6141720302915,
#                         "lng": -122.3173233697085
#                     },
#                     "southwest": {
#                         "lat": 47.6114740697085,
#                         "lng": -122.3200213302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "M\u00e9tier Seattle",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109479845758910778779\">Kimberly Pham</a>"
#                     ],
#                     "photo_reference": "AcYSjRhlz6961RJATgUXa6qcKQBk2ygsQdNFGlRym9NtLZWxCkMeJKegOf8GYFlg2AG8_6pRvkR8g8b_5LNUrG_l1a-vy5BCrb6b4fs1Eh_JXd3-iyHg7dZLZjjdjYJJLQ27O-L4tEjkvR4TVPOZzr_oAYsVIUHPq1fmuO0sUx4mFXesg5FH",
#                     "width": 3000
#                 }
#             ],
#             "place_id": "ChIJsRdC0AcVkFQR-M_ZN_wWOgU",
#             "plus_code": {
#                 "compound_code": "JM7J+3G Seattle, WA, USA",
#                 "global_code": "84VVJM7J+3G"
#             },
#             "rating": 4.4,
#             "reference": "ChIJsRdC0AcVkFQR-M_ZN_wWOgU",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "health",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 108,
#             "vicinity": "1017 East Union Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6150781,
#                     "lng": -122.3277934
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.61635913029149,
#                         "lng": -122.3265029197085
#                     },
#                     "southwest": {
#                         "lat": 47.61366116970849,
#                         "lng": -122.3292008802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "Rapha Seattle",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107568480008065606410\">Rachel Park</a>"
#                     ],
#                     "photo_reference": "AcYSjRirjeTr_P-ZUBQeJhuDBQBPYw2oeXe9AzcTOtlf3HlH-YJv6rQqq68Lx-3858sY5yMQw8dAWXEOaq8rY3hYlaDGIVhg7jtDA5ssTLsnehoUOstS6y7NA3N9d6tK4tTPPhf0dcK4b9urtf6JFhohtUdNfSht3TDGEt5xqw_2hq8D28M",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJD8j-K8tqkFQRxaf5FFiDUeg",
#             "plus_code": {
#                 "compound_code": "JM8C+2V Seattle, WA, USA",
#                 "global_code": "84VVJM8C+2V"
#             },
#             "rating": 4.7,
#             "reference": "ChIJD8j-K8tqkFQRxaf5FFiDUeg",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "cafe",
#                 "clothing_store",
#                 "food",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 118,
#             "vicinity": "301 East Pine Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6159838,
#                     "lng": -122.3353308
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6173806802915,
#                         "lng": -122.3339287197085
#                     },
#                     "southwest": {
#                         "lat": 47.6146827197085,
#                         "lng": -122.3366266802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "MBR Bike Shop",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3672,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103645242770530988062\">Blair Daly</a>"
#                     ],
#                     "photo_reference": "AcYSjRgpdqjFd8K9EXgcLAuD_ieKrpke61bouq1Wi0veJrmPbq6TfvcJMybsrP_bY106V7NyXEpjbB9m8qEAAUdnqYvYusgq8wZM2lzdqQeUvGuysjavp9uhbwFQB8MgAZWzGZxSB9QR0au03JrVLY1H2h2iQ6XW6I0_g5IIzAskiiiWDJnE",
#                     "width": 7676
#                 }
#             ],
#             "place_id": "ChIJxx8siEoVkFQRf-LYmhygEug",
#             "plus_code": {
#                 "compound_code": "JM87+9V Seattle, WA, USA",
#                 "global_code": "84VVJM87+9V"
#             },
#             "rating": 4.3,
#             "reference": "ChIJxx8siEoVkFQRf-LYmhygEug",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 47,
#             "vicinity": "1961 9th Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6157017,
#                     "lng": -122.3408793
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6171177802915,
#                         "lng": -122.3394714197085
#                     },
#                     "southwest": {
#                         "lat": 47.6144198197085,
#                         "lng": -122.3421693802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "Velo Bike Shop",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105746056324544705882\">Velo Bike Shop</a>"
#                     ],
#                     "photo_reference": "AcYSjRhjFUW9mMeb73-b0myNWqr4VxcAePZhEJfYYD9zwB6lWke20A5xj8O_rPI6kDjyJaV4ZtPTsDODvkCJu4wAADC2rkiPAs8fSD788ELtScGaD59Fqk6YIjnC95pEoQlJ5pauyJpjGDsVcj7aAQLxvgbFTqT9jdJ3HNeS7qxg2gmZG611",
#                     "width": 1504
#                 }
#             ],
#             "place_id": "ChIJKTKBss1qkFQR7soJvq6mDCg",
#             "plus_code": {
#                 "compound_code": "JM85+7J Seattle, WA, USA",
#                 "global_code": "84VVJM85+7J"
#             },
#             "rating": 4,
#             "reference": "ChIJKTKBss1qkFQR7soJvq6mDCg",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "parking",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 140,
#             "vicinity": "2151 6th Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6136493,
#                     "lng": -122.3177578
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6150043802915,
#                         "lng": -122.3165952697085
#                     },
#                     "southwest": {
#                         "lat": 47.6123064197085,
#                         "lng": -122.3192932302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "Good Weather Bicycle & Caf\u00e9",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104241906108733953361\">Good Weather Bicycle &amp; Caf\u00e9</a>"
#                     ],
#                     "photo_reference": "AcYSjRhLP98uCq3aMTNE8ex8Ol-Bc2RTxRIDTe_cPCNwlw6RoG4Kmmz0qTiA2h8BuXx75HWo1bYsF6APu4T-e4nmtaTXA3hBpmGYnZ0lvwcixhkBu87gKVOAYKMyimUNPZUfwA0JX0t2-e3DJMW7ROM5LsfSQAdYggIyOq7-C8kwoTXivwkQ",
#                     "width": 2000
#                 }
#             ],
#             "place_id": "ChIJ7b3xss1qkFQRESZrR5_st9Y",
#             "plus_code": {
#                 "compound_code": "JM7J+FV Seattle, WA, USA",
#                 "global_code": "84VVJM7J+FV"
#             },
#             "rating": 4.9,
#             "reference": "ChIJ7b3xss1qkFQRESZrR5_st9Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "clothing_store",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 201,
#             "vicinity": "In the Alley, 1424 11th Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.5995842,
#                     "lng": -122.3337956
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.60093278029149,
#                         "lng": -122.3323187697085
#                     },
#                     "southwest": {
#                         "lat": 47.5982348197085,
#                         "lng": -122.3350167302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "Back Alley Bike Repair",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2161,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112059489151811791830\">Back Alley Bike Repair</a>"
#                     ],
#                     "photo_reference": "AcYSjRibBu0rA_lYKJN07XQDEjwbhGLbwvzbNw5S6hlTdmktdZDeZbLugAV1qDWrJtNwKGXEeGbNA54W850nTny9n94NxGz0g5btQAd_HyDMgG3s_xv52UY3a-IaSMYwrmSC5-hp-rnsY6avHxaGAr74stfDvX5TjBjCK82qeqKjoOEULWsO",
#                     "width": 2161
#                 }
#             ],
#             "place_id": "ChIJ8TJK36RqkFQRkxFMSDYBHPA",
#             "plus_code": {
#                 "compound_code": "HMX8+RF Seattle, WA, USA",
#                 "global_code": "84VVHMX8+RF"
#             },
#             "rating": 4.7,
#             "reference": "ChIJ8TJK36RqkFQRkxFMSDYBHPA",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "car_repair",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 85,
#             "vicinity": "314 1st Avenue South, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.59653539999999,
#                     "lng": -122.3337356
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.59784293029149,
#                         "lng": -122.3325944697085
#                     },
#                     "southwest": {
#                         "lat": 47.5951449697085,
#                         "lng": -122.3352924302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "Swift Industries",
#             "photos": [
#                 {
#                     "height": 3464,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116235535720836120090\">Swift Industries</a>"
#                     ],
#                     "photo_reference": "AcYSjRgP-fM8bvf8ScJMo957eQBbto2-CftudkJ4YFXsJEN_9uRTKH_CE4LBF1fRuLS4iAnqA0c0hiG-HmXKDYGdnthzdix2tdw1N9Mm9GbBGdEDa_MVHth03XEaENdkMi-uYudiMGzPE7KMB0tSpP5oYoq6o7XaWVGSPHLRITNZoLK2acGu",
#                     "width": 4618
#                 }
#             ],
#             "place_id": "ChIJ95o1mLcVkFQRcxbb56BamUg",
#             "plus_code": {
#                 "compound_code": "HMW8+JG Seattle, WA, USA",
#                 "global_code": "84VVHMW8+JG"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ95o1mLcVkFQRcxbb56BamUg",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 23,
#             "vicinity": "558 1st Avenue South, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.5978381,
#                     "lng": -122.3329336
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.5991827802915,
#                         "lng": -122.3317538197085
#                     },
#                     "southwest": {
#                         "lat": 47.5964848197085,
#                         "lng": -122.3344517802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "Footworks Cycles",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 608,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117257110406593893633\">Nigel Ellis</a>"
#                     ],
#                     "photo_reference": "AcYSjRjJuycIYWXo-n_i07AfzmGdvMni2DWpmZCAMJR09MrPosy6JEO8e6qQELby80yV-_A6gYpa-S77VOOFwhkkCSwd8nEFmgpdSzBXJTl-vlsWwGJm0-RTc-sNw0bsoffozMo9E_jDiMUjeE13F0pcwffzYk6ZU9d9RlLEvv0vcrMuQ4WJ",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJLeOHaGFrkFQRtZ2ki8Vfr74",
#             "plus_code": {
#                 "compound_code": "HMX8+4R Seattle, WA, USA",
#                 "global_code": "84VVHMX8+4R"
#             },
#             "rating": 4.3,
#             "reference": "ChIJLeOHaGFrkFQRtZ2ki8Vfr74",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "520 Occidental Avenue South Unit 311, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.5947779,
#                     "lng": -122.3095662
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.5960698302915,
#                         "lng": -122.3081024697085
#                     },
#                     "southwest": {
#                         "lat": 47.5933718697085,
#                         "lng": -122.3108004302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "The Bikery",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115646932378493753955\">Kyle Counter</a>"
#                     ],
#                     "photo_reference": "AcYSjRjqG6HUATeoBj0Jc6GXNvpALRfBQ2x065S3F5QODm_t8iIDb8qmwhkGwTtbg-z3pf3syI0gmCkjZ8IcRMw-3-c3yxJmipXMdFY4MR0QsAMalHJYJK-88I1dADGVvEvX4HMALI8XUd11z2RDcVkfxkPREFJnqabHsju0Dw9XaBpnB3T0",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJL1F6hb9qkFQRphAbgsrd6tM",
#             "plus_code": {
#                 "compound_code": "HMVR+W5 Seattle, WA, USA",
#                 "global_code": "84VVHMVR+W5"
#             },
#             "rating": 4.8,
#             "reference": "ChIJL1F6hb9qkFQRphAbgsrd6tM",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 31,
#             "vicinity": "845 Hiawatha Place South, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6175743,
#                     "lng": -122.3401405
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6186740802915,
#                         "lng": -122.3391582197085
#                     },
#                     "southwest": {
#                         "lat": 47.61597611970851,
#                         "lng": -122.3418561802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "VanMoof",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2659,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111639843461437587103\">VanMoof</a>"
#                     ],
#                     "photo_reference": "AcYSjRhx8wSIrH1rC0ZTuSr95fz0ebgYmOg_6D8JgYDauA7XepjEyDyTz428Kljw4l7wwhMsavdJJwEUiz7oVyZIWQZ8KpUEj2USRFIZInc-CtBxsDHaQ_Pyx_YeZnPGnLTk7nO0EbMF1iA7DiB5FXC_ctM_xiZMp047ORaCowSVdix8JQls",
#                     "width": 5000
#                 }
#             ],
#             "place_id": "ChIJQ9mAKG8VkFQRj053rjioJFM",
#             "plus_code": {
#                 "compound_code": "JM95+2W Seattle, WA, USA",
#                 "global_code": "84VVJM95+2W"
#             },
#             "rating": 3.7,
#             "reference": "ChIJQ9mAKG8VkFQRj053rjioJFM",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 73,
#             "vicinity": "2235 8th Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.620306,
#                     "lng": -122.3296238
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6215464302915,
#                         "lng": -122.3280191697085
#                     },
#                     "southwest": {
#                         "lat": 47.6188484697085,
#                         "lng": -122.3307171302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "icon_background_color": "#7B9EB0",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#             "name": "REI Bike Shop",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 599,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111564741642207065980\">REI Bike Shop</a>"
#                     ],
#                     "photo_reference": "AcYSjRjJoCAKa6fcEXnXAvRAVFcvfXHt1zF7XDQme-JSft5Y2srq2Y5Xgygx3-NRU9sP1aeBtZSS7FZ_IztAbyWWohJQK0kW1GyXHuXhmmoR2b48XnQMOzfNc73DYr7wwEWmUtTnCsBVtyLJera8vgBQCGvieOJZhHQMlonldBk5LFUIBpfy",
#                     "width": 794
#                 }
#             ],
#             "place_id": "ChIJp33CEwwVkFQRvMtOxeEYySA",
#             "plus_code": {
#                 "compound_code": "JMCC+45 Seattle, WA, USA",
#                 "global_code": "84VVJMCC+45"
#             },
#             "rating": 4.9,
#             "reference": "ChIJp33CEwwVkFQRvMtOxeEYySA",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 9,
#             "vicinity": "222 Yale Avenue North, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.5988983,
#                     "lng": -122.3088174
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6002470302915,
#                         "lng": -122.3075491197085
#                     },
#                     "southwest": {
#                         "lat": 47.59754906970851,
#                         "lng": -122.3102470802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "Dandelion Bikes",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105492475381274166843\">Carlos Sierra</a>"
#                     ],
#                     "photo_reference": "AcYSjRiGpupfo-d-Hj1yxh9Nr4h4D-HEeX6K5U61i76P408Me9SoZLtQ8fXFT3DGHD4700PUenIg3sn2XBmH27pkbGZY5LihHI_1TfvtzFZOslG9IzaC1G7la32KbCwSJI_wEVUWU7uXjkqRceJXqmua8gWmxd4UxXhBR2AgrCNm6LH0oUJA",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJKRX6W9prkFQRTqXdCD13hSQ",
#             "plus_code": {
#                 "compound_code": "HMXR+HF Seattle, WA, USA",
#                 "global_code": "84VVHMXR+HF"
#             },
#             "rating": 4.8,
#             "reference": "ChIJKRX6W9prkFQRTqXdCD13hSQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 23,
#             "vicinity": "408 18th Avenue South, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6244759,
#                     "lng": -122.3293612
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6258129302915,
#                         "lng": -122.3279166697085
#                     },
#                     "southwest": {
#                         "lat": 47.6231149697085,
#                         "lng": -122.3306146302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "Bike Swift",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1463,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104380925374848903979\">Bike Swift</a>"
#                     ],
#                     "photo_reference": "AcYSjRiX1_SVU3gkQ5fGPS8L5FmfCBjPM25_ryU6t3RKVzOa-y1HTI0Vz8TVmBKNpp2tM2Tp5ANpthu9Qhg4rsfOKC6WOpJ8kYXp3Q-fVG65tffQDSze0gSnuz5dxqM3--vbttugtDY8LGHuMTqIaKlNYG0t0SkGyMrrynRn4DlsjRRqLk9S",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ-6YsZjAVkFQR6oQuxy0_kfQ",
#             "plus_code": {
#                 "compound_code": "JMFC+Q7 Seattle, WA, USA",
#                 "global_code": "84VVJMFC+Q7"
#             },
#             "rating": 5,
#             "reference": "ChIJ-6YsZjAVkFQR6oQuxy0_kfQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 53,
#             "vicinity": "603 Eastlake Avenue East, Seattle"
#         },
#         {
#             "business_status": "CLOSED_TEMPORARILY",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6219034,
#                     "lng": -122.309672
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6233393302915,
#                         "lng": -122.3083221697085
#                     },
#                     "southwest": {
#                         "lat": 47.6206413697085,
#                         "lng": -122.3110201302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "icon_background_color": "#4B96F3",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#             "name": "thelinemtb",
#             "permanently_closed": true,
#             "place_id": "ChIJWfwjOysVkFQRr5-TgUXJPT4",
#             "plus_code": {
#                 "compound_code": "JMCR+Q4 Seattle, WA, USA",
#                 "global_code": "84VVJMCR+Q4"
#             },
#             "reference": "ChIJWfwjOysVkFQRr5-TgUXJPT4",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "store",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1705 East Harrison Street, Seattle"
#         }
#     ],
#     "status": "OK"
# }
# REI
# 222 Yale Avenue North, Seattle

# %%
# 4. Find a balloon store near the White House.
target_search = "Balloon Store"
dc_coords = "38.8976763,-77.0365298"

# redefine params
params = {
    "location": dc_coords,
    "keyword": target_search,
    "radius": radius,
    "key": gkey
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

print("Drill #4: A Balloon Store Near the White House")

# Run request
dc_balloons = requests.get(base_url, params).json()

# Print the JSON (pretty printed)
# print(json.dumps(dc_balloons, indent=4, sort_keys=True))

# Print the name and address of the first balloon shop that appears
print(dc_balloons["results"][0]["name"])
print(dc_balloons["results"][0]["vicinity"])
# Out:
# Drill #4: A Balloon Store Near the White House
# Party City
# 5522 Leesburg Pike, Falls Church

# %%
# 5. Find the nearest dentist to your house.
# Hint: Use Google Maps to find your latitude and Google Places to find
# the dentist. You may also need the rankby property.

# Google geocode to find lat, lng
my_address = "151 Sip Ave"


params = {
    "address": my_address,
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/geocode/json"

print("Drill #5: A Dentist Near My House")

my_geo = requests.get(base_url, params).json()

lat = my_geo["results"][0]["geometry"]["location"]["lat"]
lng = my_geo["results"][0]["geometry"]["location"]["lng"]


# Use lat, lng to use places API to find nearest dentist
target_search = "dentist"

params = {
    "location": f"{lat},{lng}",
    "types": target_search,
    "rankby": "distance",
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"


# Run request
response = requests.get(base_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)
my_dentist = response.json()

# Print the JSON (pretty printed)
# print(json.dumps(my_dentist, indent=4, sort_keys=True))

# Print the name and address of the first dentist that appears
print(my_dentist["results"][0]["name"])
print(my_dentist["results"][0]["vicinity"])
# Out:
# Drill #5: A Dentist Near My House
# Popper Jason DDS
# 312 Academy Street # A, Jersey City
