# %% [markdown]
# # 6.5.2 Create Heatmaps for Weather Parameters

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df
# Out:
#      City_ID                  City Country                 Date      Lat  \
# 0          0              Acapulco      MX  2022-10-09 20:20:06  16.8634
# 1          1  Vila Franca Do Campo      PT  2022-10-09 20:21:36  37.7167
# 2          2                  Jalu      LY  2022-10-09 20:21:36  29.0331
# 3          3                 Bluff      NZ  2022-10-09 20:21:36 -46.6000
# 4          4              Thompson      CA  2022-10-09 20:21:37  55.7435
# ..       ...                   ...     ...                  ...      ...
# 536      536                 Yondo      CO  2022-10-09 20:36:46   7.0062
# 537      537               Pushkar      IN  2022-10-09 20:36:46  26.5000
# 538      538            Zhezkazgan      KZ  2022-10-09 20:36:46  47.8043
# 539      539               Chifeng      CN  2022-10-09 20:36:47  42.2683
# 540      540       Bandar-E Lengeh      IR  2022-10-09 20:36:47  26.5579
#
#           Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0    -99.8901     87.62        74          75        4.61
# 1    -25.4333     75.20        90          24        5.75
# 2     21.5482     72.12        41           0        7.18
# 3    168.3333     50.81        73         100       12.46
# 4    -97.8558     53.76        43          75       12.66
# ..        ...       ...       ...         ...         ...
# 536  -73.9097     86.49        66          40        5.75
# 537   74.5500     73.69        89          16        4.94
# 538   67.7144     44.33        56           0        4.81
# 539  118.9636     36.72        49          57       23.22
# 540   54.8807     84.02        51           0        3.51
#
# [541 rows x 10 columns]

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %% [markdown]
# Next, create the heatmap for the maximum temperature. The general syntax for creating a heatmap is as follows.
#
# #1. Assign the locations to an array of latitude and longitude pairs.
# locations = [latitude, longitude]
# #2. Assign the weights variable to some values.
# temperatures = # an array of length equal to the locations array length
# #3. Assign the figure variable to the gmaps.figure() attribute.
# fig = gmaps.figure()
# #4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.
# heatmap_layer = gmaps.heatmap_layer(locations, weights=temperatures)
#
# #5. Add the heatmap layer.
# fig.add_layer(heatmap_layer)
# #6. Call the figure to plot the data.
# fig

# %%
# Heatmap of temperature 
#POSSIBLE NEGATIVE NUMBERS
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# Google heatmaps do not plot negative numbers. If you have a maximum temperature that is less than 0 °F, then you will get an InvalidWeightException error for this line of code:
#
# heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature 
#NO NEGATIVE TEMSPS (REMOVED IN FOR LOOP ABOVE)
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=temps)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# Instead of using the for loop, we can perform a list comprehension within the heatmap_layer() function.
#
# Replace temps with our code for the list comprehension so our heat_layer code looks like the following:
#
# heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])

# %%
# Heatmap of temperature 
#NO NEGATIVE TEMSPS (REMOVED IN heat_layer Code)
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of temperature 
#Adjust Heatmap Zoom, Intensity, and Point Radius
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# If you review the gmaps documentation, 
# you may notice there is a dissipation option for creating 
# heatmaps that can be added to the gmaps.heat_layer() attribute.
# Heatmap of temperature 
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create a Percent Humidity Heatmap
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create a Percent Cloudiness Heatmap
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create a Wind Speed Heatmap
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # 6.5.3 Get Vacation Criteria

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID                  City Country                 Date      Lat  \
# 0         0              Acapulco      MX  2022-10-09 20:20:06  16.8634
# 1         1  Vila Franca Do Campo      PT  2022-10-09 20:21:36  37.7167
# 5         5                Faanui      PF  2022-10-09 20:21:37 -16.4833
# 7         7             Hithadhoo      MV  2022-10-09 20:21:38  -0.6000
# 14       14                  Hilo      US  2022-10-09 20:19:50  19.7297
# 15       15             Bathsheba      BB  2022-10-09 20:21:40  13.2167
# 19       19                 Vaini      TO  2022-10-09 20:21:41 -21.2000
# 24       24                Acarau      BR  2022-10-09 20:21:43  -2.8856
# 31       31                 Kapaa      US  2022-10-09 20:18:19  22.0752
# 33       33            Vila Velha      BR  2022-10-09 20:21:25 -20.3297
#
#          Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0   -99.8901     87.62        74          75        4.61
# 1   -25.4333     75.20        90          24        5.75
# 5  -151.7500     78.64        73           3       18.59
# 7    73.0833     81.48        76         100       15.95
# 14 -155.0900     89.28        64           0        5.01
# 15  -59.5167     82.44        76         100       11.10
# 19 -175.2000     75.36        88          75       14.97
# 24  -40.1200     81.50        76          47       21.92
# 31 -159.3190     83.48        64           0        6.91
# 33  -40.2925     80.55        69           0       17.27

# %%
# Add the following code to a new cell and run the cell to determine if there are any null values.
preferred_cities_df.count()
# Out:
# City_ID       157
# City          157
# Country       156
# Date          157
# Lat           157
# Lng           157
# Max Temp      157
# Humidity      157
# Cloudiness    157
# Wind Speed    157
# dtype: int64

# %%
# Drop Null Values
preferred_cities_df = preferred_cities_df.dropna()
preferred_cities_df.head(10)
# Out:
#     City_ID                  City Country                 Date      Lat  \
# 0         0              Acapulco      MX  2022-10-09 20:20:06  16.8634
# 1         1  Vila Franca Do Campo      PT  2022-10-09 20:21:36  37.7167
# 5         5                Faanui      PF  2022-10-09 20:21:37 -16.4833
# 7         7             Hithadhoo      MV  2022-10-09 20:21:38  -0.6000
# 14       14                  Hilo      US  2022-10-09 20:19:50  19.7297
# 15       15             Bathsheba      BB  2022-10-09 20:21:40  13.2167
# 19       19                 Vaini      TO  2022-10-09 20:21:41 -21.2000
# 24       24                Acarau      BR  2022-10-09 20:21:43  -2.8856
# 31       31                 Kapaa      US  2022-10-09 20:18:19  22.0752
# 33       33            Vila Velha      BR  2022-10-09 20:21:25 -20.3297
#
#          Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0   -99.8901     87.62        74          75        4.61
# 1   -25.4333     75.20        90          24        5.75
# 5  -151.7500     78.64        73           3       18.59
# 7    73.0833     81.48        76         100       15.95
# 14 -155.0900     89.28        64           0        5.01
# 15  -59.5167     82.44        76         100       11.10
# 19 -175.2000     75.36        88          75       14.97
# 24  -40.1200     81.50        76          47       21.92
# 31 -159.3190     83.48        64           0        6.91
# 33  -40.2925     80.55        69           0       17.27

# %%
# Add the following code to a new cell and run the cell to determine if there are any null values.
preferred_cities_df.count()
# Out:
# City_ID       156
# City          156
# Country       156
# Date          156
# Lat           156
# Lng           156
# Max Temp      156
# Humidity      156
# Cloudiness    156
# Wind Speed    156
# dtype: int64

# %% [markdown]
# # 6.5.4 Map Vacation Criteria

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                     City Country  Max Temp      Lat       Lng Hotel Name
# 0               Acapulco      MX     87.62  16.8634  -99.8901
# 1   Vila Franca Do Campo      PT     75.20  37.7167  -25.4333
# 5                 Faanui      PF     78.64 -16.4833 -151.7500
# 7              Hithadhoo      MV     81.48  -0.6000   73.0833
# 14                  Hilo      US     89.28  19.7297 -155.0900
# 15             Bathsheba      BB     82.44  13.2167  -59.5167
# 19                 Vaini      TO     75.36 -21.2000 -175.2000
# 24                Acarau      BR     81.50  -2.8856  -40.1200
# 31                 Kapaa      US     83.48  22.0752 -159.3190
# 33            Vila Velha      BR     80.55 -20.3297  -40.2925

# %%
# Practice Using a Fixed Latitude and Longitude
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AcYSjRhhJ6Xya0YHKnfxdK2EijESXh5Wd-sif6uoKIsSZ_cRqxCcJoU0KVro1_CnrRoz_tGideT-kw9GhH-rhYRpucLQIXBtbubN5ViUaiKKePnLBrDWKglEqvGlaNNaOiUVt3Zff-v6-cTEhLMhWUZ5Vh-3ljLyF7fiiU5kfmhuQs61QiCdr-n5J0_U2lL4M18oeI3tk1B0scydd-EX8vpTTUBpsxkMTpdmgy5KAabiC_45C9IERFyqiTZV7PFb6ee4RUg0xXfY15fzazs3sh39yyJ30JsEkP58feK7HdpH46CETdY5U09ccAtwGVeFUnCmxnurHuDSfpW3qOMgLtr5xVdRUV7m2FWZroP-K1jnxTHgPVHhO9s-xmdcxQ1r7CNopKsh7r9AxT7miITw6d9xzOuUQ54bIFheESsAYVSomgSYFiREsPmXZ6Bd',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'],
#      'photo_reference': 'AcYSjRj-5w79DhZfNLjyldY7WlrtXkIkoB4gCR5gVHNgkpO-_sX-7Fqc_sBLnRCIIsV-pxc-DCbLolhgUC2Jf3ckKSE8Ya56qKngQKsWXYzZFHNrGZ7RxQDm2GEbR-fKGRvG5Sztcffmrk1dfXeLnszEfvDRzrx6gmhgnA2Le4wrFkoUWRQX',
#      'width': 5760}],
#    'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'plus_code': {'compound_code': 'V953+65 Paris, France',
#     'global_code': '8FW4V953+65'},
#    'rating': 4.2,
#    'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'scope': 'GOOGLE',
#    'types': ['gym',
#     'spa',
#     'night_club',
#     'bar',
#     'lodging',
#     'health',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 346,
#    'vicinity': '11 Rue du Temple, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944},
#     'viewport': {'northeast': {'lat': 48.85954748029151,
#       'lng': 2.347782830291502},
#      'southwest': {'lat': 48.85684951970851, 'lng': 2.345084869708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Britannique Hotel - Paris Centre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1426,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108984000175492464929">Britannique Hotel - Paris Centre</a>'],
#      'photo_reference': 'AcYSjRjOPb7iJz6mGLwiogEyyz7jSyNK66--79TqDyPfHKFLqW5FS9gRj9Q0eyJax1PwZ0CaVg3FllOtZlV2K6gHZQvPRDEZ6ACsLQeEGSxu8uB_5UiE5RPcOJ-SfA3QNzrLMAWJCqQG4rzCByAXRDfdpk_mc5tMYj1pj6V5FRXd3kQUfHYB',
#      'width': 1476}],
#    'place_id': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'plus_code': {'compound_code': 'V85W+8H Paris, France',
#     'global_code': '8FW4V85W+8H'},
#    'rating': 4.7,
#    'reference': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 742,
#    'vicinity': '20 Avenue Victoria, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8606342, 'lng': 2.3468978},
#     'viewport': {'northeast': {'lat': 48.8617746302915,
#       'lng': 2.347927730291502},
#      'southwest': {'lat': 48.8590766697085, 'lng': 2.345229769708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Citadines Les Halles Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 853,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102565262508115704337">Citadines Apart&#39;hotel Les Halles Paris</a>'],
#      'photo_reference': 'AcYSjRiag--AwCKLTzKMw6nZ8fdnXrT5Rtc7C0khpC6WalkGOond6AyuSH7xBPieQZJMySl_wqEFXSs5I0U02LnkP-NcoXcSZ-ldUbowgznjPGvUs562xFMWXKTjIUlmwIl-Ztrteq1f85ecFWp0BZJYYta5PHLKUvsovVoVNesq8sDo1zwZ',
#      'width': 1280}],
#    'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'plus_code': {'compound_code': 'V86W+7Q Paris, France',
#     'global_code': '8FW4V86W+7Q'},
#    'rating': 4.1,
#    'reference': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'scope': 'GOOGLE',
#    'types': ['city_hall',
#     'local_government_office',
#     'lodging',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 946,
#    'vicinity': '4 Rue des Innocents, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8607658, 'lng': 2.3465318},
#     'viewport': {'northeast': {'lat': 48.8620584302915,
#       'lng': 2.347692880291501},
#      'southwest': {'lat': 48.85936046970851, 'lng': 2.344994919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Novotel Paris Les Halles',
#    'photos': [{'height': 2000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111815616573299411056">Novotel Paris Les Halles</a>'],
#      'photo_reference': 'AcYSjRgAUKcDfTji6Ayp5DIraS-bFCWVI9SoOfrSqmU5zK7x4uhHdMG_ggUDqdnHn_rxg4gNCTdRakA9zQugXbijFRIP1AO6-s5sqA-X5XNta2mHkhmuhUoKJBZfWP2t4MT0FOXTMXiWf2DYNdD_vDXCHeQKmOgLQRP7fECPVUpw41H7Pt-Z',
#      'width': 3000}],
#    'place_id': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'plus_code': {'compound_code': 'V86W+8J Paris, France',
#     'global_code': '8FW4V86W+8J'},
#    'rating': 4.4,
#    'reference': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2678,
#    'vicinity': '8 Place Marguerite de Navarre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.860352, 'lng': 2.3440948},
#     'viewport': {'northeast': {'lat': 48.86165553029149,
#       'lng': 2.345549080291502},
#      'southwest': {'lat': 48.8589575697085, 'lng': 2.342851119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Ducs de Bourgogne',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1390,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101411638353598558320">Hôtel Ducs de Bourgogne</a>'],
#      'photo_reference': 'AcYSjRjxi6ZpbwdH4-aHpvLIgUHJLoG8Q8wcDAXNcYj3AOV1SzUO_NHdl6_3k4JCUu0HCmM8i26LHyLr3iQ0Rrr5NC9eZyp738doKn6nKOfyOiXa0-WEdErcZgYU9VMnAQsvqo3vxwD4Cy9BXSEWyqYzGoG5UDjcb1i2zpvlvmwBtgirdC-d',
#      'width': 2048}],
#    'place_id': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'plus_code': {'compound_code': 'V86V+4J Paris, France',
#     'global_code': '8FW4V86V+4J'},
#    'rating': 4.5,
#    'reference': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 318,
#    'vicinity': '19 Rue du Pont Neuf, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8555091, 'lng': 2.3408736},
#     'viewport': {'northeast': {'lat': 48.8569076302915,
#       'lng': 2.342319280291502},
#      'southwest': {'lat': 48.8542096697085, 'lng': 2.339621319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Citadines Saint-Germain-des-Prés Paris (Apart hotel Paris)',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113188832595116816387">Citadines Saint-Germain-des-Prés Paris (Apart Hotel Paris)</a>'],
#      'photo_reference': 'AcYSjRhHiXm-T2YV8wrQB2paRkXIV3IIExtA1mWLXPCIqCnNjKosTC2fOmG-g61ru7doEYvXMUKG5wmg1d6M95SNSby8emCUAvjq9IwuYaX_jhW2YhYLMIRYdmOgm-ntccGQB9mbWt6pEWlJpb6bfgWah299OJGd0Qpa5XhFczS-QAIVJZZM',
#      'width': 6720}],
#    'place_id': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'plus_code': {'compound_code': 'V84R+68 Paris, France',
#     'global_code': '8FW4V84R+68'},
#    'rating': 4.3,
#    'reference': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'scope': 'GOOGLE',
#    'types': ['city_hall',
#     'local_government_office',
#     'lodging',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 762,
#    'vicinity': '53 ter Quai des Grands Augustins, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8524547, 'lng': 2.3472064},
#     'viewport': {'northeast': {'lat': 48.8538838802915,
#       'lng': 2.348601530291502},
#      'southwest': {'lat': 48.8511859197085, 'lng': 2.345903569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Esmeralda',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106443224837840180239">Fraz A. Khan</a>'],
#      'photo_reference': 'AcYSjRiX4VL4une4eHTcAH9EV4KieFbQwdS_LJDrL34YDDcmEZIJcxbwf-PaxBI7hri-z_gePums9ZiWQ8TB7waMy9ZdX1zzEJXKGdBd9aLh3TpOPp7FY8f_EGBCIdSKyJ9-GjnOSbc2ss6XII_YoxH8vsEn2aFvUazYJ2Zzx1kubnEqls0B',
#      'width': 4032}],
#    'place_id': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'plus_code': {'compound_code': 'V82W+XV Paris, France',
#     'global_code': '8FW4V82W+XV'},
#    'rating': 4.1,
#    'reference': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 176,
#    'vicinity': '4 Rue Saint-Julien le Pauvre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8530901, 'lng': 2.3447174},
#     'viewport': {'northeast': {'lat': 48.8544535802915,
#       'lng': 2.345997680291501},
#      'southwest': {'lat': 48.85175561970851, 'lng': 2.343299719708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Albe Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117571951379278191466">Albe Hotel Saint Michel</a>'],
#      'photo_reference': 'AcYSjRjq4Va7XHmEf5X9R0ElpWFsdz0lONojM-RO1Qfk6sFKvG3cTqEVeZpJIYo9cazQWtmCAHK1ijbIgQWkZ45cKkORqBB1eLofLGB4B6fTLkDQGhWngeqqN6DWb8Q7HD9ijosCKQEzNDiFfYDmyNsDe-GKpF4wcqisJDF3gxB2c8Ia3kQD',
#      'width': 1600}],
#    'place_id': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'plus_code': {'compound_code': 'V83V+6V Paris, France',
#     'global_code': '8FW4V83V+6V'},
#    'rating': 4.4,
#    'reference': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 394,
#    'vicinity': '1 Rue de la Harpe, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8532403, 'lng': 2.3457375},
#     'viewport': {'northeast': {'lat': 48.85462748029149,
#       'lng': 2.347175730291502},
#      'southwest': {'lat': 48.8519295197085, 'lng': 2.344477769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Les Rives de Notre-Dame Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116242575283063930652">Michael Scholz</a>'],
#      'photo_reference': 'AcYSjRj0dEyU75LcnKjlrkD72QYblOK5Iod8O-lvDRa_jz9YCsYAPKAe9IUD2fcrsZ0SEyHzKiwbWdBE_XVB2jWVjDeq4k1XdiPDtb0UoBwJgfmvsF-21sJLixCFeC25TZh2wfS4xSus0RhnCjz4ttb6eqFYu8wKC_yV8FnN0f12KWbIK5Ky',
#      'width': 6048}],
#    'place_id': 'ChIJl7vs8-Bx5kcRfIQzq_4_XmU',
#    'plus_code': {'compound_code': 'V83W+77 Paris, France',
#     'global_code': '8FW4V83W+77'},
#    'rating': 4.6,
#    'reference': 'ChIJl7vs8-Bx5kcRfIQzq_4_XmU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 104,
#    'vicinity': '15 Quai Saint-Michel, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85184049999999, 'lng': 2.3448082},
#     'viewport': {'northeast': {'lat': 48.8531470802915,
#       'lng': 2.346121880291502},
#      'southwest': {'lat': 48.8504491197085, 'lng': 2.343423919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel 4 étoiles Parc Saint-Séverin Paris 5ème - Esprit de France',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2362,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107542132357877294567">Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France</a>'],
#      'photo_reference': 'AcYSjRjUO6iRqBC8p0OgT95zpHm8_eO0yUZ_5R4d64FfNkk9GKyi5xTTGI7zLWOL4rK7ndPReeUqSXyx0HxnCOpBr18Pax2PXVTxoPDpCvjMxpjqhuO9IdEfBRG1ieYCSk6dN0MRH2m29aZoHxmH9hJNMt3ueNUWc2VEvFIun9XI3j7OTNWn',
#      'width': 3776}],
#    'place_id': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'plus_code': {'compound_code': 'V82V+PW Paris, France',
#     'global_code': '8FW4V82V+PW'},
#    'rating': 4.6,
#    'reference': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 192,
#    'vicinity': '22 Rue de la Parcheminerie, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8518743, 'lng': 2.3463436},
#     'viewport': {'northeast': {'lat': 48.8532481802915,
#       'lng': 2.347596830291502},
#      'southwest': {'lat': 48.8505502197085, 'lng': 2.344898869708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Henri IV Rive Gauche',
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117561863517287206024">Muzafar Husain</a>'],
#      'photo_reference': 'AcYSjRggc2awgWM_QibrXho-gN6ugl5sPffTrOSEbBBBnDhzvg66wOjPrtgZZaPVt0TF33fJ2oBVdKjxgHiwqdcNZarIcyfzHUeGnX3vfHmBf8CoES2WXCODJijlQDwbzq0k_p4EsN6Penq3ofnMm_YrHDz-ckKdUPxMKp_0y1HBiDskGL4H',
#      'width': 3024}],
#    'place_id': 'ChIJ2a4f2-Bx5kcR40Wl3uv_53Y',
#    'plus_code': {'compound_code': 'V82W+PG Paris, France',
#     'global_code': '8FW4V82W+PG'},
#    'rating': 4.5,
#    'reference': 'ChIJ2a4f2-Bx5kcR40Wl3uv_53Y',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 174,
#    'vicinity': 'Rue Saint-Jacques, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8600866, 'lng': 2.3533543},
#     'viewport': {'northeast': {'lat': 48.86148808029149,
#       'lng': 2.354740780291502},
#      'southwest': {'lat': 48.85879011970849, 'lng': 2.352042819708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Beaubourg',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2684,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115421447635584539926">Hôtel Beaubourg</a>'],
#      'photo_reference': 'AcYSjRhtIbpxmUp2bwBRv-9m13TxmCn77oSVS0ZWPNg2oxqofgc4NEIpUB9-IoGcvYVThb12dwztQ9Fk1GdAuL8KOmjkia4yX3qy_Qz7Mjg1D42s2YAFg6YVfAneHTxUgad0qYVUAcs2SwY0qeJf1BBvTixgRXEoLkB2ML0OToX0ZJdMvbiP',
#      'width': 5937}],
#    'place_id': 'ChIJCdHKjhxu5kcR0YtyGr7Vftc',
#    'plus_code': {'compound_code': 'V963+28 Paris, France',
#     'global_code': '8FW4V963+28'},
#    'rating': 4.3,
#    'reference': 'ChIJCdHKjhxu5kcR0YtyGr7Vftc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 168,
#    'vicinity': '11 Rue Simon le Franc, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.859876, 'lng': 2.347049},
#     'viewport': {'northeast': {'lat': 48.8610872802915,
#       'lng': 2.348425880291502},
#      'southwest': {'lat': 48.8583893197085, 'lng': 2.345727919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Hôtel Des Ducs D'Anjou",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115209143941459061727">Hotel Des Ducs D&#39;Anjou</a>'],
#      'photo_reference': 'AcYSjRhxuSgtH0Jb446BbHlXKeSJMkh_sc7EcmdGNfO_ZKQ8qbCkbk9sB0cRm_twfLsYpXBy0hZj_R2ZWAZHCmQnvBoB2P0SFwB35AM3eNmLTOilev6Rh1GyZCWPA3sKVgoHCTa2qP2MltKyXZLXANncekCWWcKedVtEdmAtiuDPd4RLZ_Sv',
#      'width': 1352}],
#    'place_id': 'ChIJ9ekWGR9u5kcRsS8j5TnWeSE',
#    'plus_code': {'compound_code': 'V85W+XR Paris, France',
#     'global_code': '8FW4V85W+XR'},
#    'rating': 3.9,
#    'reference': 'ChIJ9ekWGR9u5kcRsS8j5TnWeSE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 338,
#    'vicinity': '1 Rue Sainte-Opportune, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8515237, 'lng': 2.3486679},
#     'viewport': {'northeast': {'lat': 48.8529256302915,
#       'lng': 2.349962130291502},
#      'southwest': {'lat': 48.8502276697085, 'lng': 2.347264169708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Maison Colbert Member of Meliá Collection',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3656,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102194778927204133336">Hotel Maison Colbert Member of Meliá Collection</a>'],
#      'photo_reference': 'AcYSjRgwob2rDF_5QjZM3LuOjShAXYQEh1v1NAQhmBC0_zCEJAr1YvsGJ5v8YRlW8A20p23XQg71W1I8bdxYmf4IYmu8cAthnIvLGb3NRA4vKJymFRZIY5d6stsnoOTOlXumEccQ2XhTAk4LpmZGNOoR6P9PBF_FIjkHcW51G7f_GfSdFLGS',
#      'width': 3543}],
#    'place_id': 'ChIJI3vbSOFx5kcR84E4IeL2LqI',
#    'plus_code': {'compound_code': 'V82X+JF Paris, France',
#     'global_code': '8FW4V82X+JF'},
#    'rating': 4.7,
#    'reference': 'ChIJI3vbSOFx5kcR84E4IeL2LqI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 26,
#    'vicinity': "7 Rue de l'Hôtel Colbert, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8499446, 'lng': 2.346247699999999},
#     'viewport': {'northeast': {'lat': 48.8513264802915,
#       'lng': 2.347622530291501},
#      'southwest': {'lat': 48.8486285197085, 'lng': 2.344924569708497}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Home Latin',
#    'photos': [{'height': 4080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113966656287531023757">Ioan Mihael</a>'],
#      'photo_reference': 'AcYSjRiq-Ieh7FPFMQN8pzgq1X7WCliNaRSG468GzuTO1rGj-FF9rVCCS-zd2Vkrx8EYj8EJfLnU5YvVjIunGtN5haE50YSmOpRG5iZkKxSdUJP9ENKMo_uyBI3corOKKzmwlVTn-TEhBOnND2FYCibVtEDe-PHVpt4ERNErmG21dwglfxRg',
#      'width': 3072}],
#    'place_id': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'plus_code': {'compound_code': 'R8XW+XF Paris, France',
#     'global_code': '8FW4R8XW+XF'},
#    'rating': 3.4,
#    'reference': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 370,
#    'vicinity': '15-17 Rue du Sommerard, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8514465, 'lng': 2.3495407},
#     'viewport': {'northeast': {'lat': 48.85276158029151,
#       'lng': 2.350874680291501},
#      'southwest': {'lat': 48.85006361970851, 'lng': 2.348176719708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Les Degrés de Notre Dame',
#    'photos': [{'height': 1984,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115564994803632359392">christophe etter</a>'],
#      'photo_reference': 'AcYSjRhuD_AJbxYhuGlgJ6681g9EtGnh29EIvRKheAKgL0E-2bKrYzjcAi9UxsAPlHPtepJZObG3VS-RG4odyivJQ1FV_TPjBVi5xl6cNicfFicAXJLtqZPfe0yJO3kIYsGgnHCt2_3PGncemq5Zo0WCfoq1AUFYzIt_8EeO4s1du3tMkvQz',
#      'width': 3968}],
#    'place_id': 'ChIJMyUCVOFx5kcRcLsa7V0Y1m4',
#    'plus_code': {'compound_code': 'V82X+HR Paris, France',
#     'global_code': '8FW4V82X+HR'},
#    'rating': 3.8,
#    'reference': 'ChIJMyUCVOFx5kcRcLsa7V0Y1m4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 78,
#    'vicinity': '10 Rue des Grands Degrés, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85221300000001, 'lng': 2.3420703},
#     'viewport': {'northeast': {'lat': 48.8535826302915,
#       'lng': 2.343484980291502},
#      'southwest': {'lat': 48.8508846697085, 'lng': 2.340787019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Du Lys',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101676196871616220179">Scouser1965</a>'],
#      'photo_reference': 'AcYSjRi9Q6x5E4mczxa9GZ1vwX8TCUtyxi4LmW5fdhWEfj2CC3ITbAYiKpZwGGmbZrTR40809DcrskV0TEbbr2vTJxV082xoo7kVuS8svHS4Cy_bBZwRl1UYMETXcQegZ2UwF2zmMB1CVm_mznu4n3MkNemY8Wvkh_YOOUj3SL-ENAW7Gt4N',
#      'width': 4032}],
#    'place_id': 'ChIJrcnEaN5x5kcRjjOnEG6_HHs',
#    'plus_code': {'compound_code': 'V82R+VR Paris, France',
#     'global_code': '8FW4V82R+VR'},
#    'rating': 3.8,
#    'reference': 'ChIJrcnEaN5x5kcRjjOnEG6_HHs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 252,
#    'vicinity': '23 Rue Serpente, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8607212, 'lng': 2.342585},
#     'viewport': {'northeast': {'lat': 48.8620849802915,
#       'lng': 2.343869380291502},
#      'southwest': {'lat': 48.8593870197085, 'lng': 2.341171419708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "L'Empire Paris",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1123,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112201701198428774080">L&#39;Empire Paris</a>'],
#      'photo_reference': 'AcYSjRiLsjXpus-rxZ1QpbIFEFRahdVHqY1DlzGJbTDm9IarxovwiM14MlKU-nF0OFmSH-p2gWk2qYUkUtp7dET5OmaqZP-FnI9Pr6oVi3dJOPD-n-pSlsLOoX3NsyDNh9UXdxoWEMyd-38-CTwYVypMSk5ObaNhdcahVtJLRmS7KiLILfeS',
#      'width': 2000}],
#    'place_id': 'ChIJ0Wj4hCFu5kcRQ67Hb2M6b9Q',
#    'plus_code': {'compound_code': 'V86V+72 Paris, France',
#     'global_code': '8FW4V86V+72'},
#    'rating': 4.2,
#    'reference': 'ChIJ0Wj4hCFu5kcRQ67Hb2M6b9Q',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 502,
#    'vicinity': "48 Rue de l'Arbre Sec, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85924579999999,
#      'lng': 2.341004799999999},
#     'viewport': {'northeast': {'lat': 48.8606175802915,
#       'lng': 2.342363980291502},
#      'southwest': {'lat': 48.8579196197085, 'lng': 2.339666019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Relais Du Louvre',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108368902339576647054">Joe Belknap Wall</a>'],
#      'photo_reference': 'AcYSjRh40QC2dgBMVQ7qeS3Eu5f3SLilEVugqt1k5iJAlLzUr0r2EDozsxxqUnbax426Ek0L5gLNQqXP9EubEuh7YmhZWQTS483Ln0Uksh2OvYfvKdLCll_tXgznug4fLJXQTEdTSghT_CAZ6-emlkS1TE_ZqoKEnnI9fD5eQrYAasQbbvlM',
#      'width': 3024}],
#    'place_id': 'ChIJb4ExGiFu5kcRx-LufqT5JSw',
#    'plus_code': {'compound_code': 'V85R+MC Paris, France',
#     'global_code': '8FW4V85R+MC'},
#    'rating': 4.6,
#    'reference': 'ChIJb4ExGiFu5kcRx-LufqT5JSw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 144,
#    'vicinity': "19 Rue des Prêtres Saint-Germain l'Auxerrois, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8632711, 'lng': 2.352693},
#     'viewport': {'northeast': {'lat': 48.86461498029149,
#       'lng': 2.353958580291502},
#      'southwest': {'lat': 48.8619170197085, 'lng': 2.351260619708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Georgette',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1181,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112851757923591367842">Hôtel Georgette</a>'],
#      'photo_reference': 'AcYSjRjXj2FSW_CuLXPVb5J7FIAJMJkIt44N2a1JYZRHLamOFGsWO3whOLMUXKmUx5bO21LbA7YaobGAnTfwFAeR1Sz3MDBsleyB0mLUgsGpOaEZJj_f5rFBtGhJ_Ahp9X25ZIfe35qRtDyz8JTjFmdnosZzmNCR-0oM9gqgG3vH91KBFP6N',
#      'width': 1772}],
#    'place_id': 'ChIJZ6OWsRtu5kcRuyOkJ6_e06E',
#    'plus_code': {'compound_code': 'V973+83 Paris, France',
#     'global_code': '8FW4V973+83'},
#    'rating': 4.4,
#    'reference': 'ChIJZ6OWsRtu5kcRuyOkJ6_e06E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 227,
#    'vicinity': '36 Rue du Grenier-Saint-Lazare, Paris'}],
#  'status': 'OK'}

# %%
# NOT RUNNING SINCE IT IS DESIGNED TO NOT RUN AND HAVE AN ERROR 
# Iterate Through hotel_df DataFrame
# Iterate through the DataFrame.

# for index, row in hotel_df.iterrows():
#     # Get the latitude and longitude.
#     lat = row["Lat"]
#     lng = row["Lng"]

#     # Add the latitude and longitude to location key for the params dictionary.
#     params["location"] = f"{lat},{lng}"

#     # Use the search term: "lodging" and our latitude and longitude.
#     base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#     # Make request and get the JSON data from the search.
#     hotels = requests.get(base_url, params=params).json()
#     # Grab the first hotel from the results and store the name.
#     hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]

# %%
# Iterate Through hotel_df DataFrame
# Iterate through the DataFrame.
# With TRY EXCEPT Block 
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    #Here is the --- TRY EXCEPT BLOCK --- 
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df
# Out:
#                      City Country  Max Temp      Lat       Lng  \
# 0                Acapulco      MX     87.62  16.8634  -99.8901
# 1    Vila Franca Do Campo      PT     75.20  37.7167  -25.4333
# 5                  Faanui      PF     78.64 -16.4833 -151.7500
# 7               Hithadhoo      MV     81.48  -0.6000   73.0833
# 14                   Hilo      US     89.28  19.7297 -155.0900
# ..                    ...     ...       ...      ...       ...
# 530                 Tanda      IN     76.77  26.5500   82.6500
# 533              Buchanan      LR     77.58   5.8808  -10.0467
# 535               Merauke      ID     78.30  -8.4667  140.3333
# 536                 Yondo      CO     86.49   7.0062  -73.9097
# 540       Bandar-E Lengeh      IR     84.02  26.5579   54.8807
#
#                              Hotel Name
# 0             HS Hotsson Smart Acapulco
# 1                   Pestana Bahia Praia
# 5    Bora-Bora Pearl Beach Resort & Spa
# 7                     Scoop Guest House
# 14                  Hilo Hawaiian Hotel
# ..                                  ...
# 530                   MUMTAZ GANJ TANDA
# 533                 Kamaneahn Hotel Inc
# 535
# 536    estacion sayab sede la felicidad
# 540                        کافی نت پارس
#
# [156 rows x 6 columns]

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# From the gmaps documentation on how to add markersLinks to an external site., we need to add an info_box_template that has the following syntax.
#
# info_box_template = """
# <dl>
# <dt>Name</dt><dd>{column1}</dd>
# <dt>Another name</dt><dd>{column2}</dd>
# </dl>
# """

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
hotel_info
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd>HS Hotsson Smart Acapulco</dd>\n<dt>City</dt><dd>Acapulco</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>87.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pestana Bahia Praia</dd>\n<dt>City</dt><dd>Vila Franca Do Campo</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Max Temp</dt><dd>75.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bora-Bora Pearl Beach Resort & Spa</dd>\n<dt>City</dt><dd>Faanui</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>78.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Scoop Guest House</dd>\n<dt>City</dt><dd>Hithadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Max Temp</dt><dd>81.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hilo Hawaiian Hotel</dd>\n<dt>City</dt><dd>Hilo</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>89.28 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Atlantis Hotel</dd>\n<dt>City</dt><dd>Bathsheba</dd>\n<dt>Country</dt><dd>BB</dd>\n<dt>Max Temp</dt><dd>82.44 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Keleti Beach Resort</dd>\n<dt>City</dt><dd>Vaini</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Max Temp</dt><dd>75.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>castelo pizzaria</dd>\n<dt>City</dt><dd>Acarau</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>81.5 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sheraton Kauai Coconut Beach Resort</dd>\n<dt>City</dt><dd>Kapaa</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>83.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Vitória Palace</dd>\n<dt>City</dt><dd>Vila Velha</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>80.55 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Comfort Inn Hotel</dd>\n<dt>City</dt><dd>Madang</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>75.43 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Vivant Residence</dd>\n<dt>City</dt><dd>Vicosa</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>79.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Storyboard Beach Resort</dd>\n<dt>City</dt><dd>Kloulklubed</dd>\n<dt>Country</dt><dd>PW</dd>\n<dt>Max Temp</dt><dd>84.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nuli Sapi</dd>\n<dt>City</dt><dd>Samarai</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>80.96 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express Pascagoula-Moss Point, an IHG Hotel</dd>\n<dt>City</dt><dd>Moss Point</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>82.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sur Plaza Hotel</dd>\n<dt>City</dt><dd>Sur</dd>\n<dt>Country</dt><dd>OM</dd>\n<dt>Max Temp</dt><dd>80.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express Lompoc, an IHG Hotel</dd>\n<dt>City</dt><dd>Lompoc</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>81.7 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Auki Motel</dd>\n<dt>City</dt><dd>Auki</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Max Temp</dt><dd>77.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Country Inn & Suites by Radisson, Norman, OK</dd>\n<dt>City</dt><dd>Norman</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>76.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>البوكمال</dd>\n<dt>City</dt><dd>Abu Kamal</dd>\n<dt>Country</dt><dd>SY</dd>\n<dt>Max Temp</dt><dd>75.7 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Cititel Penang</dd>\n<dt>City</dt><dd>Georgetown</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>79.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nuba Nile</dd>\n<dt>City</dt><dd>Aswan</dd>\n<dt>Country</dt><dd>EG</dd>\n<dt>Max Temp</dt><dd>80.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Porto Praia</dd>\n<dt>City</dt><dd>Arraial Do Cabo</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>75.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Red Sea Resort & Suites Mandera County</dd>\n<dt>City</dt><dd>Mandera</dd>\n<dt>Country</dt><dd>KE</dd>\n<dt>Max Temp</dt><dd>83.86 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Swiss-Belhotel Ambon</dd>\n<dt>City</dt><dd>Ambon</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>77.14 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tanna Lodge</dd>\n<dt>City</dt><dd>Isangel</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Max Temp</dt><dd>76.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maui Seaside Hotel</dd>\n<dt>City</dt><dd>Kahului</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>84.97 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Adam's Villa</dd>\n<dt>City</dt><dd>Pathri</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>75.36 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>SanBiz Lodge</dd>\n<dt>City</dt><dd>Kirakira</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Max Temp</dt><dd>79.41 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Poum</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Max Temp</dt><dd>75.83 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grage Hotel Bengkulu</dd>\n<dt>City</dt><dd>Bengkulu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>75.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Manglares</dd>\n<dt>City</dt><dd>Tecoanapa</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>85.82 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Fakhamat Al Orjoana Apartment</dd>\n<dt>City</dt><dd>Sakakah</dd>\n<dt>Country</dt><dd>SA</dd>\n<dt>Max Temp</dt><dd>80.17 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Bara</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Max Temp</dt><dd>79.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Villa Enata</dd>\n<dt>City</dt><dd>Atuona</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>76.96 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Dibbo areaمنطقة دبو</dd>\n<dt>City</dt><dd>Kutum</dd>\n<dt>Country</dt><dd>SD</dd>\n<dt>Max Temp</dt><dd>79.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Conrad Bora Bora Nui</dd>\n<dt>City</dt><dd>Vaitape</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>78.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Tari</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Max Temp</dt><dd>85.69 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Isles Sunset Lodge</dd>\n<dt>City</dt><dd>Butaritari</dd>\n<dt>Country</dt><dd>KI</dd>\n<dt>Max Temp</dt><dd>82.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Paradise Inn</dd>\n<dt>City</dt><dd>Avarua</dd>\n<dt>Country</dt><dd>CK</dd>\n<dt>Max Temp</dt><dd>75.25 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shah Madina Hotel</dd>\n<dt>City</dt><dd>Kashmor</dd>\n<dt>Country</dt><dd>PK</dd>\n<dt>Max Temp</dt><dd>81.59 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sylvia Hotel</dd>\n<dt>City</dt><dd>Maumere</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>80.35 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Best Western Plus Abbey Inn</dd>\n<dt>City</dt><dd>Saint George</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>84.94 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Luba</dd>\n<dt>Country</dt><dd>GQ</dd>\n<dt>Max Temp</dt><dd>76.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express & Suites Tooele, an IHG Hotel</dd>\n<dt>City</dt><dd>Tooele</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>76.86 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sea Lounge! Bar, Club & Restaurant</dd>\n<dt>City</dt><dd>Itarema</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>81.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Green leaf</dd>\n<dt>City</dt><dd>Kavaratti</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>80.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Shyam</dd>\n<dt>City</dt><dd>Ghazipur</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>79.68 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Steve Walden and Emma Sison-Walden Residence</dd>\n<dt>City</dt><dd>Aloleng</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>79.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Rumboat Retreat</dd>\n<dt>City</dt><dd>Gouyave</dd>\n<dt>Country</dt><dd>GD</dd>\n<dt>Max Temp</dt><dd>81.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Yos ega cv</dd>\n<dt>City</dt><dd>Boyolangu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>75.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>VIHARI GRAND INN</dd>\n<dt>City</dt><dd>Markapur</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>75.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Inn Of The Hills Hotel & Conference Center</dd>\n<dt>City</dt><dd>Kerrville</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>86.52 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Auberge Alferdaous</dd>\n<dt>City</dt><dd>Tatawin</dd>\n<dt>Country</dt><dd>TN</dd>\n<dt>Max Temp</dt><dd>78.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Cortez Malaga Techy Caroly</dd>\n<dt>City</dt><dd>Iquitos</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Max Temp</dt><dd>89.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Piesta</dd>\n<dt>City</dt><dd>Trinidad</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Max Temp</dt><dd>89.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Vivi Palace</dd>\n<dt>City</dt><dd>Matadi</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Max Temp</dt><dd>80.96 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ana Villadiego Monrroy</dd>\n<dt>City</dt><dd>Chivolo</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Max Temp</dt><dd>85.77 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lorengau Harbourside Hotel</dd>\n<dt>City</dt><dd>Lorengau</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>80.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tour Eiffel Hotel Benin</dd>\n<dt>City</dt><dd>Porto Novo</dd>\n<dt>Country</dt><dd>BJ</dd>\n<dt>Max Temp</dt><dd>77.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Aracati Hotel</dd>\n<dt>City</dt><dd>Tefe</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>87.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Porto De Canoas</dd>\n<dt>City</dt><dd>Sao Joao Da Barra</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>78.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Arena Blanca</dd>\n<dt>City</dt><dd>San Andres</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Max Temp</dt><dd>84.22 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Club Hotel Eilat</dd>\n<dt>City</dt><dd>Elat</dd>\n<dt>Country</dt><dd>IL</dd>\n<dt>Max Temp</dt><dd>80.44 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Le Martin Pecheur</dd>\n<dt>City</dt><dd>Jacqueville</dd>\n<dt>Country</dt><dd>CI</dd>\n<dt>Max Temp</dt><dd>78.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pine Tree Motel</dd>\n<dt>City</dt><dd>Katherine</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>75.52 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mercure Padang</dd>\n<dt>City</dt><dd>Padang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>78.12 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>El Salvial</dd>\n<dt>City</dt><dd>Tomatlan</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>88.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kost Pria</dd>\n<dt>City</dt><dd>Meulaboh</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>76.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Fazenda 4 cantos</dd>\n<dt>City</dt><dd>Ladario</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>75.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pob Choke Residences ( พบโชคเรดซิเด้นท์ )</dd>\n<dt>City</dt><dd>Sattahip</dd>\n<dt>Country</dt><dd>TH</dd>\n<dt>Max Temp</dt><dd>77.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Windy Lodge & Beach Resort</dd>\n<dt>City</dt><dd>Winneba</dd>\n<dt>Country</dt><dd>GH</dd>\n<dt>Max Temp</dt><dd>76.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Clevers Hotel Chiredzi</dd>\n<dt>City</dt><dd>Chiredzi</dd>\n<dt>Country</dt><dd>ZW</dd>\n<dt>Max Temp</dt><dd>77.34 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>INN NEW HORIZON</dd>\n<dt>City</dt><dd>Touros</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>79.07 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Imagination Island</dd>\n<dt>City</dt><dd>Gizo</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Max Temp</dt><dd>81.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>እንደገና ገዋኔ ሞቴል</dd>\n<dt>City</dt><dd>Gewane</dd>\n<dt>Country</dt><dd>ET</dd>\n<dt>Max Temp</dt><dd>88.84 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Jardin</dd>\n<dt>City</dt><dd>Puerto El Triunfo</dd>\n<dt>Country</dt><dd>SV</dd>\n<dt>Max Temp</dt><dd>83.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Reserva do Abiaí</dd>\n<dt>City</dt><dd>Pitimbu</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>82.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nusa Island Retreat</dd>\n<dt>City</dt><dd>Kavieng</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>80.73 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Minshuku Agaihama</dd>\n<dt>City</dt><dd>Nishihara</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Max Temp</dt><dd>78.08 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Dora, Bubaque</dd>\n<dt>City</dt><dd>Bubaque</dd>\n<dt>Country</dt><dd>GW</dd>\n<dt>Max Temp</dt><dd>81.72 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Best Inn Hotel, Restaurant, Convention</dd>\n<dt>City</dt><dd>Feni</dd>\n<dt>Country</dt><dd>BD</dd>\n<dt>Max Temp</dt><dd>76.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Paradise Bay Resort</dd>\n<dt>City</dt><dd>Ahuimanu</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>85.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Uribia</dd>\n<dt>City</dt><dd>Uribia</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Max Temp</dt><dd>82.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maitai Lapita Village Huahine</dd>\n<dt>City</dt><dd>Fare</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>78.22 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nabelchel Bungalows</dd>\n<dt>City</dt><dd>Norsup</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Max Temp</dt><dd>79.3 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Posada San Jose</dd>\n<dt>City</dt><dd>Pochutla</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>87.82 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Nathaniel's Lodge</dd>\n<dt>City</dt><dd>Basco</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>81.95 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Omadhoo Inn</dd>\n<dt>City</dt><dd>Mahibadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Max Temp</dt><dd>80.74 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pension Oaoa</dd>\n<dt>City</dt><dd>Tautira</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>77.07 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Citra</dd>\n<dt>City</dt><dd>Sabang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>81.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Quality Inn Payson I-15</dd>\n<dt>City</dt><dd>Payson</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>76.41 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Roseau Hostel & Beach Front Property</dd>\n<dt>City</dt><dd>Pointe Michel</dd>\n<dt>Country</dt><dd>DM</dd>\n<dt>Max Temp</dt><dd>77.94 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Penginapan Kim</dd>\n<dt>City</dt><dd>Biak</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>76.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Olako</dd>\n<dt>City</dt><dd>Omboue</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Max Temp</dt><dd>77.43 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Flat Quatro Rodas Olinda</dd>\n<dt>City</dt><dd>Olinda</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>80.33 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel Le Dronmi</dd>\n<dt>City</dt><dd>Cayenne</dd>\n<dt>Country</dt><dd>GF</dd>\n<dt>Max Temp</dt><dd>84.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Paradise Hotel</dd>\n<dt>City</dt><dd>Wanning</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Max Temp</dt><dd>75.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Xaguate</dd>\n<dt>City</dt><dd>Sao Filipe</dd>\n<dt>Country</dt><dd>CV</dd>\n<dt>Max Temp</dt><dd>78.33 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ujamaa Beach Resort</dd>\n<dt>City</dt><dd>Sokoni</dd>\n<dt>Country</dt><dd>TZ</dd>\n<dt>Max Temp</dt><dd>75.74 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Le Rocher</dd>\n<dt>City</dt><dd>Dzaoudzi</dd>\n<dt>Country</dt><dd>YT</dd>\n<dt>Max Temp</dt><dd>75.09 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Laguna, Bed & Breakfast</dd>\n<dt>City</dt><dd>Guerrero Negro</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>77.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sadaf Resort</dd>\n<dt>City</dt><dd>Gwadar</dd>\n<dt>Country</dt><dd>PK</dd>\n<dt>Max Temp</dt><dd>80.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Rey David</dd>\n<dt>City</dt><dd>Nata</dd>\n<dt>Country</dt><dd>PA</dd>\n<dt>Max Temp</dt><dd>85.87 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Suresh Parmar</dd>\n<dt>City</dt><dd>Tharad</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>82.22 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Posada Turistica Manapiare</dd>\n<dt>City</dt><dd>Puerto Ayacucho</dd>\n<dt>Country</dt><dd>VE</dd>\n<dt>Max Temp</dt><dd>84.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Kununurra</dd>\n<dt>City</dt><dd>Kununurra</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>76.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Gamba</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Max Temp</dt><dd>76.77 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kimbe Bay Hotel</dd>\n<dt>City</dt><dd>Kimbe</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>79.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Beija Flor</dd>\n<dt>City</dt><dd>Conde</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>81.86 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel Niara Belly</dd>\n<dt>City</dt><dd>Boffa</dd>\n<dt>Country</dt><dd>GN</dd>\n<dt>Max Temp</dt><dd>75.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>LIKWALE LODGE</dd>\n<dt>City</dt><dd>Mayumba</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Max Temp</dt><dd>76.68 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>หนองหานรีสอร์ท</dd>\n<dt>City</dt><dd>Nong Han</dd>\n<dt>Country</dt><dd>TH</dd>\n<dt>Max Temp</dt><dd>77.14 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel e Restaurante Uirapuru (Márcio uirapuru )Em São Domingos -Go</dd>\n<dt>City</dt><dd>Sao Domingos</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>81.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>hotêl doufoulougou</dd>\n<dt>City</dt><dd>Tabou</dd>\n<dt>Country</dt><dd>CI</dd>\n<dt>Max Temp</dt><dd>77.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express & Suites Snyder, an IHG Hotel</dd>\n<dt>City</dt><dd>Snyder</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>76.32 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Vila Nova Hotel</dd>\n<dt>City</dt><dd>Ponta Delgada</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Max Temp</dt><dd>75.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mantra Trilogy Cairns</dd>\n<dt>City</dt><dd>Cairns</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>75.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Welcomhotel By ITC Hotels, Bay Island, Port Blair</dd>\n<dt>City</dt><dd>Port Blair</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>80.44 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>VS Villa</dd>\n<dt>City</dt><dd>Kalmunai</dd>\n<dt>Country</dt><dd>LK</dd>\n<dt>Max Temp</dt><dd>77.59 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Orient Star Dahabyia Isna 05 Nights Each Sunday</dd>\n<dt>City</dt><dd>Esna</dd>\n<dt>Country</dt><dd>EG</dd>\n<dt>Max Temp</dt><dd>77.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Fengshui Residence</dd>\n<dt>City</dt><dd>Port-Gentil</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Max Temp</dt><dd>80.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>DoubleFAG</dd>\n<dt>City</dt><dd>Labuhan</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>79.16 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Osprey Beach Hotel</dd>\n<dt>City</dt><dd>Cockburn Town</dd>\n<dt>Country</dt><dd>TC</dd>\n<dt>Max Temp</dt><dd>81.97 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lakatoro Palm Lodge</dd>\n<dt>City</dt><dd>Lakatoro</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Max Temp</dt><dd>80.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Caxito</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Max Temp</dt><dd>75.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Foyer ADM</dd>\n<dt>City</dt><dd>Mitsamiouli</dd>\n<dt>Country</dt><dd>KM</dd>\n<dt>Max Temp</dt><dd>75.74 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Nusantara I</dd>\n<dt>City</dt><dd>Nabire</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>75.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Paraiso</dd>\n<dt>City</dt><dd>Oliveira Dos Brejinhos</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>88.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Morada feliz</dd>\n<dt>City</dt><dd>Anage</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>84.83 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Posada Llovizna Rodríguez</dd>\n<dt>City</dt><dd>San Felipe</dd>\n<dt>Country</dt><dd>VE</dd>\n<dt>Max Temp</dt><dd>75.81 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tortoise Tapu (Anay)</dd>\n<dt>City</dt><dd>Harsud</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>75.69 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Expeditions Ténére voyages</dd>\n<dt>City</dt><dd>Bilma</dd>\n<dt>Country</dt><dd>NE</dd>\n<dt>Max Temp</dt><dd>84.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nancy Montanes Bernardo</dd>\n<dt>City</dt><dd>Dicabisagan</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>76.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Aviador Hotel Boutique</dd>\n<dt>City</dt><dd>Santa Cruz</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Max Temp</dt><dd>80.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Jebinrio home</dd>\n<dt>City</dt><dd>Manavalakurichi</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>77.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Leumerus Bungalows</dd>\n<dt>City</dt><dd>Sola</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Max Temp</dt><dd>80.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Soke</dd>\n<dt>Country</dt><dd>ML</dd>\n<dt>Max Temp</dt><dd>87.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>unidiversidad organica la utopia</dd>\n<dt>City</dt><dd>Miranda</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Max Temp</dt><dd>80.73 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>University Plaza Waterfront Hotel</dd>\n<dt>City</dt><dd>San Joaquin</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>86.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Courtyard by Marriott Port of Spain</dd>\n<dt>City</dt><dd>Mucurapo</dd>\n<dt>Country</dt><dd>TT</dd>\n<dt>Max Temp</dt><dd>82.13 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>STAATS LOGEERGEBOUW TOTNESS</dd>\n<dt>City</dt><dd>Totness</dd>\n<dt>Country</dt><dd>SR</dd>\n<dt>Max Temp</dt><dd>79.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Highland Inn</dd>\n<dt>City</dt><dd>Ascension</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>85.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Savannah Inn</dd>\n<dt>City</dt><dd>Lethem</dd>\n<dt>Country</dt><dd>GY</dd>\n<dt>Max Temp</dt><dd>85.71 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Matu Island</dd>\n<dt>City</dt><dd>Brokopondo</dd>\n<dt>Country</dt><dd>SR</dd>\n<dt>Max Temp</dt><dd>80.87 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Nalut</dd>\n<dt>Country</dt><dd>LY</dd>\n<dt>Max Temp</dt><dd>75.61 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Motel 6 Sinton, TX</dd>\n<dt>City</dt><dd>San Patricio</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>89.55 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ilha Praia Hotel</dd>\n<dt>City</dt><dd>Camocim</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>81.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>ZIDA HOMESTAY</dd>\n<dt>City</dt><dd>Jenjarom</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>75.34 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Puri Brata</dd>\n<dt>City</dt><dd>Bambanglipuro</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>76.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Drury Plaza Hotel San Antonio Riverwalk</dd>\n<dt>City</dt><dd>San Antonio</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>89.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>MUMTAZ GANJ TANDA</dd>\n<dt>City</dt><dd>Tanda</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>76.77 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kamaneahn Hotel Inc</dd>\n<dt>City</dt><dd>Buchanan</dd>\n<dt>Country</dt><dd>LR</dd>\n<dt>Max Temp</dt><dd>77.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Merauke</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>78.3 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>estacion sayab sede la felicidad</dd>\n<dt>City</dt><dd>Yondo</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Max Temp</dt><dd>86.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>کافی نت پارس</dd>\n<dt>City</dt><dd>Bandar-E Lengeh</dd>\n<dt>Country</dt><dd>IR</dd>\n<dt>Max Temp</dt><dd>84.02 °F</dd>\n</dl>\n']

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
